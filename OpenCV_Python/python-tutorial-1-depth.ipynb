# %%
import cv2

# %%
import pyrealsense2

# %%
## License: Apache 2.0. See LICENSE file in root directory.
## Copyright(c) 2015-2017 Intel Corporation. All Rights Reserved.

#####################################################
## librealsense tutorial #1 - Accessing depth data ##
#####################################################

# First import the library
import pyrealsense2 as rs

try:
    # Create a context object. This object owns the handles to all connected realsense devices
    pipeline = rs.pipeline()

    # Configure streams
    config = rs.config()
    config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)

    # Start streaming
    pipeline.start(config)

    while True:
        # This call waits until a new coherent set of frames is available on a device
        # Calls to get_frame_data(...) and get_frame_timestamp(...) on a device will return stable values until wait_for_frames(...) is called
        frames = pipeline.wait_for_frames()
        depth = frames.get_depth_frame()
        if not depth: continue

        # Print a simple text-based representation of the image, by breaking it into 10x20 pixel regions and approximating the coverage of pixels within one meter
        coverage = [0]*64
        for y in range(480):
            for x in range(640):
                dist = depth.get_distance(x, y)
                if 0 < dist and dist < 1:
                    coverage[x//10] += 1
            
            if y%20 is 19:
                line = ""
                for c in coverage:
                    line += " .:nhBXWW"[c//25]
                coverage = [0]*64
                print(line)
    exit(0)
#except rs.error as e:
#    # Method calls agaisnt librealsense objects may throw exceptions of type pylibrs.error
#    print("pylibrs.error was thrown when calling %s(%s):\n", % (e.get_failed_function(), e.get_failed_args()))
#    print("    %s\n", e.what())
#    exit(1)
except Exception as e:
    print(e)
    pass
# Out:
# <>:37: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:37: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-5-ba8f46a6b43c>:37: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if y%20 is 19:
#                WWWWnWWWWn
#              :BWWWWWWWWWWX.
#             hXWWWWWWWWWWWWn:
#            :BWWX.....:BWWWn
#           .hWWX      :WWWWh..:..:
#            nWWB     XWWWWWBBBBhnBn.
#            BWW.     BWWWWWh.hB:
#           :Xn      .WWWWW:
#                 .  .WWWX.    :nn
#      hBBBXXWX:  h.:nBhhhh.  BWXh
#      hWWWWWWWW.           :hnhhXn.
#       nWWWWWWWWn      ..:hhXWWWWn:.
#       h:WWWWWWXnnn   .XXnnhWWWWWBXh
#       :XWh:::nh.   :  :hhnnhBBXXXnn
#       .WW.  nhXB  ..   .  .:nn   .n.
#        hh:hXWX:         .Bh      nBh:BXWWWWWB
#                     .               :BXXWXWWX
#                                  :n :BXXWhhn.
#                                   .:BXWWXXWW.
#                                      :..nnBn
#                                          BW.
#                                          WW
#                                          Wh
#                                          XB
#                WWWWnWWWXn
#              .BWWWWWWWWWWB.
#             hXWWWWWWWWWWWWh:
#            hWWWX......BWWWn
#           .BWWX      :WWWWn..:...
#            nWWX     XXWWWWhhBhn:n:.
#           .BWW:     BWWWWWh:B:
#           nWB      .WWWWW:
#             ::      WWWX.    :nn
#     :BBBBXXWB:  h  nBBBh:.  hWXh
#     .WWWWWWWWW.           nXnhhWXh.
#      nnWWWWWWWWn      ..:hnWWWWWB:.
#       ..WWWWWWXn.:   .XB:nhWWWWWXBn
#       .XWn::nnh.      :... .nnBBh:.
#       hWW.  nhh:          ::h:    :
#        ::.nXWX:         hXB.:.   :BBn:hBBXXXB
#                                     .h:nXWWWB
#                                        .hhhn
#                                        :BXWW
#                                        .n:.:
#                                          hW.
#                                          WW
#                                          WB
#       .                                  WX
#                XWWWBWWWW:
#               hWWWWWWWWWWh
#              :WWWWWWWWWWWWn
#            :WWWB..  ..nWWWh
#           nBWWB       XWWh
#           .hWW:     .nWWWW.
#          .nWWW.     hWWWW:
#           nh.      hWWWWW:
#            n.      XWWWWW:::nn::
#       BBXXXWB.  BnBWWBWBWBBXWWWWn.
#     : BWWWWWWW.       WWWWWWWWWWWWB
#        XWWWWWWWXWXhnBWWWWWWWWWWWWWB
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWX:.        .
#       .BWWWWWWWWXBBBWWWWWXWWWWWWWWWXX:     .hXB
#        nBWWWWWWB   nhnhXWBhnh:n.::h.:.  .::.::.
#        :::BWXXB:     .n.:Xh     :WWXXBBXXnhWWh
#        .hBXXBBhn:.    hWWWWWXhBXXXXWWWWWWWWWW.
#      ..      ..:nhBXXBBhhhn:::nhBXXWWWWBWXWWX
#                       .:hhBXXXBhnn:....::nBW
#                               .:nhBXWWXBBXWn
#       .                               .:nXW.
#                                          XW
#                                          XB
#                                          BX
#                XWWXBWWWW:
#               nWWWB:hXWWWh
#              .WWXB:   nWWWn
#             :WWX     nBWWWh
#           hWWWB     .WWWWh
#           :XWW:      :WWW:
#            XWW:      XWWW.
#           :..       .WWWW.
#           :hh:      .WWWW     .:.
#       BXXXXXh  .X: nWBWWW:   .XWWW:
#       BWWWWWWW:.Bn   .WWW:.:nXWWWWX
#        XWWWWWWWWWXnXBBBXWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn::....:n:::
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .XWWWWWWWWWXWWWWWWWWWXXn    :n:::nn::BXW.
#        XWWWWWWWWWWWWWWWWWWXnB  nBBWXWXBXXBhWWh
#        .hXXWWWWWWWWWWWWWWWWWWWXWWWXWWWWWWWWWW.
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWX
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nXX
#                                          XW
#                                          XB
#                                          BB
#                XWWh :XWW:
#               nWWh    WWWh
#              .WWB     :WWWn
#             nWWW     BWWWWh
#           BWWWX.     :WWWh
#           :XWW:      :WWW:
#           :XWW:      WWWW:
#                     .WWWW:
#           .Bn       nWWWW     .:
#       BXXXXWh  .XXhWWBWWW:   .WWWW.
#       hWWWWWWWh:Xhn: .WWWnnhhXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#       :.WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::..::::::
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWXXWWWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWBBhhhB::BWh
#        :hXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          hB
#                XWWh:WWWW:
#               nWWW: ..WWWB
#              .WWW:    XWWWn
#             hWWW     .WWWWh
#           hWWWX.     :WWWh
#           .XWW:      :WWW:
#            XWW:      XWWW:
#            ..       .WWWW:
#            .        :WWWW.    .:
#       BXXXWWh  .h.  XBWWW:    BWWW.
#       BWWWWWWWn.Bh   .WWWnnnhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::::::::::
#        nWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWXBBBhhhBWh
#        .hXXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nXX
#                                          XW
#        .                                 XX
#                                          BB
#                XWWWWBXWW:
#               nWWWX. nWWWh
#              .WWXB.   BWWWn
#             hWWW    .WWWWWh
#           BWWWX.    :XWWWh
#          .:XWW:     .hWWW:
#           :XWWn      XWWW:
#             .       .WWWW:
#            :h:     .:WWWW.    .:
#       BXXXXXh  .XhBWWBWWW:    XWWW.
#       BWWWWWWWh:Bh:. .WWWnnhnBWWWWX
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::::::::::
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWBBXXWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWXBBhhhBBnXWh
#        :hXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          nh
#                XWWn BWWW:
#               nWWB  :hWWWh
#              .WWB     XWWWn
#             hWWW     hXWWWh
#           nWWWX.    :WWWWh
#           .BWW:      hWWW:
#            BWW:     .WWWW:
#             .       .WWWW:
#            hBn      .WWWW.    .:
#       BXXXXWB  .B:nXWBWWW:   .BWWW.
#       BWWWWWWWn.XBn: .WWWnnhhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       ..WWWWWWWWWWWWWWWWWWWWWWWWWWWn:....:::n::
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWBBXXXWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWBhBhn:n:XWh
#        .hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          hB
#                XWW:.:WWW:
#               hWWX. .nWWWh
#              .WWB     nWWWn
#             hWWW    .BXWWWh
#           hWWWX.    :BWWWh
#           nXWW:      :WWW:
#            BWW:      XWWW:
#             .       .WWWW:
#            nhn      :WWWW     .:
#       BXXXXWh  .XhhhWBWWW:   .XWWW.
#       BWWWWWWWn.Bh:. :WWWnnhnXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::..::nnn:
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       :XWWWWWWWWWXXWWWWWWWWWWWWWWWWWXBWWXWWWWW:
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWhhnnnhBXWh
#        .hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       .nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          nh
#                XWWh..XWW:
#               nWWBh::nWWWh
#              .WWBn    nWWWn
#             nWWW     BWWWWh
#           XWWWX.    nWWWWh
#          .:BWW:      hWWW:
#          ..BWW:      WWWW:
#             :       :WWWW:
#            nn.      :WWWW.    .:
#       BXXXXXn  .X:.XWBWWW:   :XWWW.
#       BWWWWWWXn.Bh.. :WWWnnhhWWWWWB
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWn::::::::::n
#        hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW:
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWXXhBXB:hWh
#        .hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          XB
#                XWWXhWWWW:
#               nWWWB..nWWWh
#              .WWB.    XWWWn
#             nWWW     .BWWWh
#           XWWWX.     .WWWh
#           nXWW:      :WWW:
#            BWWn      XWWW:
#             .       .WWWW:
#            nn       :WWWW.    .:.
#       BXXXXWh  .Wn:XWBWWW:    BWWW.
#       BWWWWWWWn.hn.. .WWWnnnhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::::::nhhn
#       :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWWBXXWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWBBBBBBhBWh
#        :hXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          BB
#                XWWhnhWWW:
#               nWWWX  BWWWh
#              .WWWWB  :XWWWn
#             hWWW     XBWWWh
#           XWWWX.    nXWWWh
#           :XWW:      :WWW:
#           .XWW:     .XWWW:
#             :      .:WWWW:
#            hh.     nnWWWW.    .: .
#       BXXXXWh  .WhnWWBWWW:   .WWWW.
#       XWWWWWWWn.Bh   .WWWnnnhXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWnn:.::::::.:
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWBBXWWWWWWWW:
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWXBhhhhBhXXWh
#        .hXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#       .                                  nh
#                XWWBnXWWW:
#               nWWWh BBWWWh
#              .WWWXn   :WWWn
#             nWWW     BXWWWh
#           nBWWX.     hWWWh
#           .XWW:      :WWW:
#            BWW.      XWWW:
#             .       .WWWW:
#            .        :WWWW     .:
#       BXXXWXh  .B..WXBWWW:    XWWW.
#       BWWWWWWWn.h:   :WWWnnnhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::::::n:::
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWXXWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWXXh::hBXWh
#        .hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 BX
#                                          hB
#                XWW: hWWW:
#               nWWX   .WWWh
#              .WWW:    hWWWn
#             nWWW     nXWWWh
#           BWWWX.     BWWWh
#          .:XWW:      :WWW:
#            BWW:      XWWW:
#             :       .WWWW:
#           nBhn     ::WWWW.    .:
#       XXXXWWh  .Xh.:WBWWW:   .XWWW.
#       BWWWWWWWn.BBn  .WWWnnhhXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::::::nn::
#        nWWWWWWWWWWWWWWWWWWWWWWWWWXWWWWWWWWWWWWX
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWBXXWWWWWWWW.
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWXBhhhnhnXWh
#        :hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          BB
#                XWWWWXWWW:
#               nWWWX  hWWWh
#              .WWB.    hWWWn
#             hWWX     hXWWWh
#           BWWWX      .WWWh
#           :XWW:      :WWW:
#            XWW:      XWWW:
#            .:       .WWWW:
#           .Bn       :WWWW.    .: .
#       BXXXXWh  .Xn XWBWWW:   .XWWW.
#       BWWWWWWWn.Bh:. .WWWnnnnXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::.:::n:::
#        nWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWBXXXWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWXBhnnhBhnXWh
#        .hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          XB
#                XWWXBWWWW:
#               nWWWB :nWWWh
#              .WWWW.  :BWWWn
#             hWWW    .hXWWWh
#           nWWWX     :nWWWh
#           .XWW:      :WWW:
#            BWX.     :XWWW:
#            .:      .nWWWW:
#           :BB:      :WWWW     .:
#       BXXXXWB  .Xn nWBWWW:   .BWWW.
#       BWWWWWWWn.Bn.. .WWWhnnBWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::::::::::
#        WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWXWWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWXXhhhn::BWh
#        :hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          BW
#        .                                 XX
#                                          nh
#                XWWXhBWWW:
#               nWWXh.:nWWWh
#              .WWB:    nWWWn
#             nWWW     .hWWWh
#           BWWWX.    nWWWWh
#           nXWW:      :WWW:
#            BWW.      XWWW:
#            .:       .WWWW:
#           nWh:      .WWWW.    .:.
#       BXXXWWh  .XB:nWBWWW:    BWWW.
#       BWWWWWWWn:XB:. .WWWnnnnhWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:....::nnn:
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       :WWWWWWWWWWWWWWWWWWWWWWWWWWWWXBXXXXXWWWW:
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWXBBhnnh:.BWh
#        :hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nXX
#                                          XW
#        .                                 BX
#                                          hB
#                XWWB:BWWW:
#               nWWWh:nhWWWh
#              .WWXB:  .hWWWn
#             nWWW     :XWWWh
#           nWWWX.     nWWWh
#           .XWW:      :WWW:
#            BWW.      XWWW:
#             :      n:WWWW:
#           .hn       :WWWW.     :
#       BXXXXXh  .WBBWWBWWW:    BWWW.
#       BWWWWWWXh.Bhn. :WWWnnnhBWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn::..:::::::
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWXXBXXXWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWXBh:.nhBWh
#        :hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          hB
#                XWW:  XWW:
#               nWWB    WWWh
#              .WWWh    nWWWn
#             hWWW     hXWWWh
#           BWWWX.     hWWWh
#           .XWWn      :WWW:
#            XWW:      XWWW:
#           .         .WWWW:
#           nB        :WWWW.    .:
#       BXXXWWh  .XXhXWBWWW:   .WWWW.
#       BWWWWWWWn:XX:  .WWWnnnhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::.:::nn::
#        hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW:
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWXBhBhhhBWn
#        :hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          XB
#                XWWB.nWWW:
#               nWWXn  .WWWh
#              .WWB     hWWWn
#             nWWW     BXWWWh
#           hWWWX.     nWWWh
#          .nXWW:      nWWW:
#            XWW.      XWWW:
#             .       :WWWW:
#            hBn.     :WWWW.    .:
#       BXXXXWh  .Bn:WWBWWW:   .XWWW:
#       BWWWWWWXn:Xh . .WWWhnhhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWnn:::::::nnn
#        nWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWXXWWWWWWWWWW.
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWXBhhnhXXXWWh
#        .hXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 BX
#                                          ::
#                XWWh .XWW:
#               nWWn   :WWWh
#              .WWXn    nWWWn
#             nWWW     nXWWWh
#           nXWWX.    :WWWWh
#            XWW:      :WWW:
#            BWW:      XWWW:
#                     .WWWW:
#            : .      :WWWW.    .: .
#       BXXXXWh  .WX:nXBWWW:   .XWWW.
#       BWWWWWWWn.hh:  .WWWhnhhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWn::..::::hhn
#        nXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWBBBXXWWWWWW:
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWXBBhhBhnBBWh
#        :hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       .nhBBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#                                          BX
#                                          :n
#                XWWWWWWWW:
#               nWWXn..:WWWh
#              .WWWX.   hWWWn
#             hWWW    :BXWWWh
#           .WWWX.    hXWWWh
#            XWW:      :WWW:
#            XWW.      XWWW:
#             :       .WWWW:
#            h:       :WWWW.    .:
#       BXXXXWh  .Wh:BWBWWW:   .XWWW.
#       BWWWWWWWn.BB.. .WWWnnhhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn::..:::::::
#        nWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .XWWWWWWWWWWXWWWWWWWWWWWWWWWWBBBXWXWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWXBhhhBhnBWh
#        .hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 BX
#                                          nn
#                BWWB nWWW:
#               nWWWB.XXWWWh
#              .WWBn    hWWWn
#             nWWX     hWWWWh
#           hWWWX     hWWWWh
#           .XWW:     .BWWW:
#          .nWWW:     .XWWW:
#             .       .WWWW:
#            :        :WWWW.    .: .
#       BXXXWXh  .Wn.XWBWWW:   .BWWW.
#       BWWWWWWWn.hn.  :WWWhnnhWWWWWX
#        XWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::..::nnn:
#        nWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWXXXXBhhBWh
#        .hXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nXX
#                                          XW
#        .                                 XX
#                                          :n
#                XWW. .XWW:
#               nWWWn:hhWWWh
#              .WWWX:  :hWWWn
#             nWWW     hXWWWh
#           XWWWX     .BWWWh
#           hXWW:      hWWW:
#           nXWW:      XWWW:
#             :       :WWWW:
#            hBn     .:WWWW.    .:
#       BXXXXWh  .XXXWWBWWW:    BWWW.
#       BWWWWWWWn.hnn: .WWWnnnnWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn::..:::nn:n
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .WWWWWWWWWWWXWWWWWWWWWWWWWWWWBBXXXXWWWWW:
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWXBhhBnXXWWWh
#        .hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          XB
#                XWWB..WWW:
#               nWWWX  hWWWh
#              .WWWB:   nWWWn
#             hWWW    .BWWWWh
#           XWWWX.    BWWWWh
#           .XWW:      nWWW:
#           :XWW.      WWWW:
#             .       .WWWW:
#           nX:       :WWWW.    .:
#       BXXXWWn  .XXBnWBWWW:    BWWW.
#       BWWWWWWWn.BB:. .WWWnnhnXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn::.:nnnhhn:
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWBBBXBXWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWXBBBBhh:hBWh
#        :hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          hh
#                XWWn:XWWW:
#               nWWWh  :WWWh
#              .WWXX.  .hWWWn
#             hWWX    .XWWWWh
#           XWWWX      nWWWh
#            XWW:      :WWW:
#            BWW.      XWWW:
#             .       .WWWW:
#           :Bh:     .:WWWW.    .: .
#       BXXXXWh  .XXBWWBWWW:    BWWW:
#       BWWWWWWWn.BBn: .WWWnnhhXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       :.WWWWWWWWWWWWWWWWWWWWWWWWWWWn::..::::nn:
#        hXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWBBBXXXWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWBhBhn.nhBWh
#        :hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          :n
#                XWWXnhWWW:
#               nWWW  .:WWWh
#              .WWXh   .BWWWn
#             hWWW     hXWWWh
#           XWWWX.     :WWWh
#          .:XWW:      nWWW:
#            BWW:      XWWW:
#             :       .WWWW:
#            .:.      nWWWW     .:
#       BXXXWXh  .XnnXWBWWW:    BWWW.
#       BWWWWWWWn:Bh:. .WWW:nhhBWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:..::::nhn:
#        nWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWBBBWWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWXBBhnnhnBWWh
#        :hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       .nhhBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          BB
#                XWWn nWWW:
#               nWWXn nBWWWh
#              .WWXh   .BWWWn
#             nWWW     nXWWWh
#           nWWWX.     :WWWh
#            BWW:      :WWW:
#            BWW:     .WWWW:
#            .:       :WWWW:
#            hn.      :WWWW.    .:..
#       BXXXXWh  .X::XWBWWW:   :WWWW.
#       BWWWWWWXn.Bhn  :WWWhnhhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::.:::nnn:
#        nWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWBXWWWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWBBBhhBnnXWh
#        .hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:hhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          hB
#                XWWBnBWWW:
#               nWWB:  nWWWh
#              .WWX.    hWWWn
#             hWWW      XWWWh
#           BWWWX.     nWWWh
#           :XWW:      BWWW:
#            BWW:     :WWWW:
#            .:      .nWWWW:
#            hh:     hhWWWW.    .: .
#       BXXXXWh  .BnhXWBWWW:    XWWW.
#       BWWWWWWWh:XXn. .WWWhnnnXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::.:::::::
#        nWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .WWWWWWWWWWWXWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWXXXBXBWWWh
#        .hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          hh
#                XWWBnhWWW:
#               nWWXn   XWWh
#              .WWB     :WWWn
#             hWWW     BWWWWh
#           nWWWX.    .BWWWh
#           .XWW:      :WWW:
#            XWW:      XWWW:
#           :::       :WWWW:
#           .Bn.      :WWWW     .:
#       BXXXWWn  .X:XXWBWWW:    XWWW.
#       hWWWWWWWn.BBh. .WWW:nnhXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWn::::::::n::
#        :XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .XWWWWWWWWWWXWWWWWWWWWWWWWWWWBBXWWWWWWWW.
#        XWWXWWWWWWWWWWWWWWWWWWWWWWWXBBBhhBnhBWh
#        :hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nXX
#                                          XW
#        .                                 XX
#                                          hB
#                XWWn nWWW:
#               nWWWn :nWWWh
#              .WWXh    hWWWn
#             nWWX     nWWWWh
#           nWWWX     :hWWWh
#           .XWW:      hWWW:
#            BWW:      XWWW:
#            .:       :WWWW:
#           :Bhn      :WWWW     .: .
#       BBXXWXh  .WXBXWBWWW:   .BWWW.
#       hWWWWWWWn.Bh:. .WWWnnnnXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#       ::WWWWWWWWWWWWWWWWWWWWWWWWWWWn::...:::n::
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       :WWWWWWWWWWWWWWWWWWWWWWWWWWWWXWWWWWWWWWW.
# ...
#           :XWW:      :WWW:
#            BWW.      XWWW:
#             n       nWWWW:
#           .BB:     nBWWWW.    .:
#       BXXXWWh  .Wn.XWBWWW:   :XWWW.
#       BWWWWWWXn:Xh.. :WWWnnhnWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWn::...:::::n
#        hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .WWWWWWWWWWWXWWWWWWWWWWWWWWWXXXWWWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWBXBBhB:nXWn
#        .hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 BX
#                                          :h
#                XWWWWWWWW:
#               nWWWh :BWWWh
#              .WWB.    BWWWn
#             nWWX     hXWWWh
#           XWWWX      hWWWh
#           nXWWn      nWWW:
#          .:BWW:      XWWW:
#            .:       .WWWW:
#            h.       :WWWW.    .:
#       BXXXXXh  .Bn:WWBWWW:   .XWWW.
#       BWWWWWWXn:XB.  .WWW:nnhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::..::::nn
#        hXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       :XWWWWWWWWWWWWWWWWWWWWWWWWWWWXXXXXXWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWBBBBBXhnXWh
#        :hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          hB
#                XWWXnXWWW:
#               nWWWW.n:WWWh
#              .WWWXn   BWWWn
#             nWWW     :WWWWh
#           hWWWX     .BWWWh
#           :XWW:      BWWW:
#           :XWW:      XWWW:
#            ..       .WWWW:
#            Bn.      :WWWW.    .:
#       BXXXXWh  .B. nWBWWW:    BWWW.
#       BWWWWWWWn.Bn   .WWWnnhnBWWWWB
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:...:::::::
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWXBBXXWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWXXXBn:nXWh
#        :hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nBXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          hB
#                XWW. :XWW:
#               nWWW:  hWWWh
#              .WWX:    :WWWn
#             nWWW    .XXWWWh
#           BWWWX     nWWWWh
#           .XWW:      hWWW:
#            BWW       XWWW:
#             .       .WWWW:
#            :n.    .BhWWWW.    .:.
#       BXXXXWh  .XWWWWBWWW:    XWWW.
#       BWWWWWWWn:BXh. .WWWnnnnXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::::::::nn
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWBXXWWWWWWWW:
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWBBhBBBn:BWh
#        :hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#               .:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nXX
#                                          XW
#                                          XX
#                                          hB
#                XWWW:nWWW:
#               nWWXh :BWWWh
#              .WWWXn  :hWWWn
#             nWWW     XBWWWh
#           BWWWX.    .BWWWh
#           .XWW:      :WWW:
#            BWW.     .XWWW:
#             .       :WWWW:
#           hX:      .:WWWW     .:
#       BXXXWWh  .XBhWWBWWW:   .WWWW.
#       BWWWWWWWn.BB:. .WWWnnnhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#        .WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::::::::::
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWBhBXWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWXXhhhXnnXWh
#        :hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          hh
#                BWWXnnWWW:
#               nWWB   :WWWh
#              .WWWB    hWWWn
#             hWWW    .BXWWWh
#           :WWWX      .WWWh
#           .XWW:      hWWW:
#            BWW.      XWWW:
#                     .WWWW:
#           nBhn.    .:WWWW     .: .
#       BXXXWWh  .XXBXWBWWW:   .XWWW.
#       BWWWWWWXn.Bh.  :WWWnnnnWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWXWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:...:n:::::
#        hXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .XWWWWWWWWWWXWWWWWWWWWWWWWWWWXXBBXWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWXBhhnnhn:XWh
#        :hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#       .                                  nn
#                XWW. .XWW:
#               nWWWhnnhWWWh
#              .WWXXB  .hWWWn
#             nWWW    :XWWWWh
#           :WWWX.    BWWWWh
#            XWW:      nWWW:
#            BWW:     .XWWW:
#             .       .WWWW:
#           .hn:      :WWWW.    .:.
#       BXXXXWh  .B: WWBWWW:   .XWWW.
#       BWWWWWWWh.Bn . .WWWnnnhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::::::::nn
#        hWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWWWXXhhnnBWh
#        .hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       .nhhBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#                                          XX
#                                          nh
#                XWWB:hWWW:
#               nWWWB: .WWWh
#              .WWX:    nWWWn
#             nWWW.    nXWWWh
#           XWWWX.     BWWWh
#           :WWW:      :WWW:
#            XWW.      XWWW:
#             :       .WWWW:
#            :        nWWWW.    .:
#       BXXXXXn  .B. nWBWWW:   .WWWW.
#       BWWWWWWWn.B:   .WWWnnnnXWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn:::::nnn:nn
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWBBBXBXWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWXBhnBXXXWWh
#        .hBXWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhhBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nXX
#                                          XW
#        .                                 XX
#                                          :n
#                XWWB :WWW:
#               nWWX.   WWWh
#              .WWWB.   hWWWn
#             nWWX     nBWWWh
#           hWWWX     :XWWWh
#           .XWW:      :WWW:
#            BWW       XWWW:
#                     .WWWW:
#            h       ::WWWW.    .:
#       BXXXWWh  .B.:WWBWWW:    XWWW.
#       BWWWWWWWn.Bhn: .WWWnnnhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       :.WWWWWWWWWWWWWWWWWWWWWWWWWWWn::..:::.:::
#        :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWX
#       .XWWWWWWWWWWWWWWWWWWWWWWWWWWWBWWWWWWWWWW.
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWWWXhnnhBnXWn
#        :hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhXXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 XX
#                                          hB
#               .XWWB:hWWW:
#               nWWWW.nWWWWB
#              .WWh     BWWWn
#             nWWW     nBWWWh
#           hWWWX.    :BWWWh
#           :XWWn      hWWW:
#           :BWW:      XWWW:
#            ..       .WWWW:
#                     :WWWW.    .:
#       BXXXXXh  .Wn.BWBWWW:    BWWW.
#       BWWWWWWXn.Bh:  .WWWhnnhWWWWWX
#        BWWWWWWWWWWWWWWWWWWWWWWWWWWX
#         WWWWWWWWWWWWWWWWWWWWWWWWWWWn::..::::..:
#        :WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWB
#       .WWWWWWWWWWWWWWWWWWWWWWWWWWWWBBXWWWWWWWW.
#        XWWWWWWWWWWWWWWWWWWWWWWWWWWWXBWXBXBhXWh
#        .hBWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW.
#              ..:hBXXWWWWWWWWWWWWWWWWWWWWWWWWB
#                       :nhBBXWWWWWWWWWWWWWWWX
#                               .:nhBXWWWWWWW:
#                                       .:nBX
#                                          XW
#        .                                 BX
#                                          :n
#                XWWWWWWWW:
#               nWWWh  .WWWh
#              .WWWWh   hWWWn
#             nWWW.     hWWWh
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ba8f46a6b43c> in <module>
#      31         for y in range(480):
#      32             for x in range(640):
# ---> 33                 dist = depth.get_distance(x, y)
#      34                 if 0 < dist and dist < 1:
#      35                     coverage[x//10] += 1
#
# KeyboardInterrupt:
